# %% [markdown]
# <a href="https://colab.research.google.com/github/Piyush007k/EDA-on-play-store-dataset/blob/main/EDA_on_play_store_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Play Store App Review Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**Piyush Kale

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **BUSINESS PROBLEM OVERVIEW**
#
# The Play Store Apps Analysis is important for any app company's or bussiness,as it recognize the client needs and the type of app the client prefers.
#
# In Play Store Clients/Users are able to choose from multiple apps.It is very competitive platform.These platform are open for all and it has varites of options.Their are many stakes involved in app's growth. The Play Store has many
# Categories and lot of potential for app developing comapany,but for the app to succeced, Company should have insights on how the most popular apps work engage and succeced in Play store.
#
# First step for the app companies is to find out how engage and succeced app's work and then explore and analyse the Play Store data to achieve this.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **Find out key factors responsible for app's engagement and success**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
Play_Store_data=pd.read_csv('Play Store Data.csv')
reviews=pd.read_csv('User Reviews.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
Play_Store_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
reviews
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
rows = Play_Store_data.shape[0]
cols = Play_Store_data.shape[1]
rows=str(rows)
cols=str(cols)
print('Play_Store_data Rows: '+ rows)
print('Play_Store_data Columns: '+ cols)

rows = reviews.shape[0]                                   #reviews.shape  o/p:(8486, 5)
cols = reviews.shape[1]
rows=str(rows)
cols=str(cols)
print('\nReviews Rows: '+ rows)
print('Reviews Columns: '+ cols)  #reviews
# Out:
# Play_Store_data Rows: 10841
# Play_Store_data Columns: 13
#
# Reviews Rows: 64295
# Reviews Columns: 5

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
Play_Store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate=Play_Store_data[Play_Store_data.duplicated('App')]
duplicate1=reviews[reviews.duplicated('Translated_Review')]
print(len(duplicate))
print(len(duplicate1))
duplicate
# Out:
# 1181
# 36300
#                                       App       Category  Rating  Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10715                  FarmersOnly Dating         DATING     3.0     1145
# 10720  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10730                         FP Notebook        MEDICAL     4.5      410
# 10753      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10768                                AAFP        MEDICAL     3.8       63
#
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_data=Play_Store_data.isnull().sum()
missing_data
missing_data_1=reviews.isnull().sum()
missing_data_1
print("Missing data in PlayStore data: \n"+str(missing_data))
print("Missing data in Review data: \n"+str(missing_data_1))
# Out:
# Missing data in PlayStore data:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               1
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64
# Missing data in Review data:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Visualizing the missing values
# Checking Null Value by plotting Barplot
missing_data.plot(kind='bar')
plt.xlabel='Columns'
plt.ylabel='Count'
plt.title='Missing data'
plt.show()

# %%
missing_data_1.plot(kind='bar')
plt.xlabel='Columns'
plt.ylabel='Count'
plt.title='Missing data'

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The data is provide by playstore and as to files 1st is Play store app date and other is app review.
#
# From this data we have to find a meaningfull insight so that our app could grab more engagement and succeced in play store.Using this Play Store Data we will able to predict the engagment and success of the app.
#
# The Play Store dataset has 10841 rows and 13 columns.
# The Review dataset has 10841 rows and 13 columns.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(Play_Store_data.columns)
print(reviews.columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
Play_Store_data.describe(include='all')
# Out:
#            App Category       Rating       Reviews                Size  \
# count    10841    10841  9367.000000  1.084100e+04               10841
# unique    9660       33          NaN           NaN                 461
# top     ROBLOX   FAMILY          NaN           NaN  Varies with device
# freq         9     1972          NaN           NaN                1695
# mean       NaN      NaN     4.191513  4.441119e+05                 NaN
# std        NaN      NaN     0.515735  2.927629e+06                 NaN
# min        NaN      NaN     1.000000  0.000000e+00                 NaN
# 25%        NaN      NaN     4.000000  3.800000e+01                 NaN
# 50%        NaN      NaN     4.300000  2.094000e+03                 NaN
# 75%        NaN      NaN     4.500000  5.476800e+04                 NaN
# max        NaN      NaN     5.000000  7.815831e+07                 NaN
#
#           Installs   Type  Price Content Rating Genres    Last Updated  \
# ...

# %%
reviews.describe(include='all')
# Out:
#                         App Translated_Review Sentiment  Sentiment_Polarity  \
# count                 64295             37427     37432        37432.000000
# unique                 1074             27994         3                 NaN
# top     Angry Birds Classic              Good  Positive                 NaN
# freq                    320               247     23998                 NaN
# mean                    NaN               NaN       NaN            0.182146
# std                     NaN               NaN       NaN            0.351301
# min                     NaN               NaN       NaN           -1.000000
# 25%                     NaN               NaN       NaN            0.000000
# 50%                     NaN               NaN       NaN            0.150000
# 75%                     NaN               NaN       NaN            0.400000
# max                     NaN               NaN       NaN            1.000000
#
#         Sentiment_Subjectivity
# ...

# %%
len(Play_Store_data['Category'].value_counts())
# Out:
# 33

# %% [markdown]
# ### Variables Description

# %% [markdown]
# # Play Store Dataset
#
#
#
# *   **App**:Contains names of the apps present in the playstore.
#
# *   **Category**:Their are taltal 34 types of categories
# *   **Rating**:Rating of the app,which is out of five.
# *   **Reviews**:Number of reviews given by the people.
# *   **Size**:Size of the given applicate.
# *   **Installs**:numbers of people who has install the app.
# *   **Type**:Type says wheather it is Free or Paid.
# *   **Price**:If the app is paid,it contains the price.
# *   **Content** Rating:Rating given to the content on the app.
# *   **Genres**:It is genres of app.
# *   **Last Updated**:The date on which the app os updated.
# *   **Current Ver**:Current version number of app.
# *   **Android Ver**:The android version which it supports.
#
#
#
#
# # **Review Dataset**
#
# *   **App**:Contains names of the apps present in the playstore.
#
# *   **Translated_Review**:Writen reviews of the Users.
#
# *   **Sentiment**:Contains sentiments towared apps present in the playstore.(Positive,Neagative,Neutral)
#
# *   **Sentiment_Polarity**:Contains sentiments towared apps present in the playstore in numbers.
#
# *   **Sentiment_Subjectivity**:Contains sentiments towared apps present in the playstore in numbers.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.                   #important Learn
for i in Play_Store_data.columns.tolist():
  print("No. of unique values in ",i,"is",Play_Store_data[i].nunique(),".")
# Out:
# No. of unique values in  App is 9660 .
# No. of unique values in  Category is 33 .
# No. of unique values in  Rating is 39 .
# No. of unique values in  Reviews is 6001 .
# No. of unique values in  Size is 461 .
# No. of unique values in  Installs is 21 .
# No. of unique values in  Type is 2 .
# No. of unique values in  Price is 92 .
# No. of unique values in  Content Rating is 6 .
# No. of unique values in  Genres is 119 .
# No. of unique values in  Last Updated is 1377 .
# No. of unique values in  Current Ver is 2783 .
# No. of unique values in  Android Ver is 33 .

# %%
for i in reviews.columns.tolist():
  print("No. of unique values in ",i,"is",reviews[i].nunique(),".")
# Out:
# No. of unique values in  App is 1074 .
# No. of unique values in  Translated_Review is 27994 .
# No. of unique values in  Sentiment is 3 .
# No. of unique values in  Sentiment_Polarity is 5410 .
# No. of unique values in  Sentiment_Subjectivity is 4474 .

# %%
Play_Store_data.nunique()
# Out:
# App               9660
# Category            33
# Rating              39
# Reviews           6001
# Size               461
# Installs            21
# Type                 2
# Price               92
# Content Rating       6
# Genres             119
# Last Updated      1377
# Current Ver       2783
# Android Ver         33
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#First step will be cleaning the data as it has lots of dupicate values and missing/duplicate values.
Play_Store_data=Play_Store_data.drop_duplicates('App')
Play_Store_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#First step will be cleaning the data as it has lots of dupicate values and missing/duplicate values.
reviews=reviews.drop_duplicates('Translated_Review')
reviews
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
#Now we will find null value if present and then replace it.
Play_Store_data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               1
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
#using mean imputation
playstore_mean=Play_Store_data['Rating'].mean()
playstore_mean = round(playstore_mean, 1)
playstore_mean
Play_Store_data['Rating']=Play_Store_data['Rating'].fillna(playstore_mean)
Play_Store_data
# Out:
# <ipython-input-22-2af6695c35ac>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Play_Store_data['Rating']=Play_Store_data['Rating'].fillna(playstore_mean)
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# ...

# %%
Play_Store_data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            1
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
Play_Store_data['Type']=Play_Store_data['Type'].fillna('Unknown')
# Out:
# <ipython-input-24-caa1bbd3c12e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Play_Store_data['Type']=Play_Store_data['Type'].fillna('Unknown')

# %%
Play_Store_data['Android Ver']=Play_Store_data['Android Ver'].fillna('Unknown version')
# Out:
# <ipython-input-25-902fff890382>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Play_Store_data['Android Ver']=Play_Store_data['Android Ver'].fillna('Unknown version')

# %%
Play_Store_data['Current Ver']=Play_Store_data['Current Ver'].fillna('Unknown version')
# Out:
# <ipython-input-26-4e904dca9b77>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Play_Store_data['Current Ver']=Play_Store_data['Current Ver'].fillna('Unknown version')

# %%
Play_Store_data['Content Rating']=Play_Store_data['Content Rating'].fillna('Unknown')
# Out:
# <ipython-input-27-6e3f6fa333fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Play_Store_data['Content Rating']=Play_Store_data['Content Rating'].fillna('Unknown')

# %%
Play_Store_data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            1
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
#Converting datatype of Prices
Play_Store_data['Price'] = Play_Store_data['Price'].str.replace('$', '').astype(float)
# Out:
# <ipython-input-29-c5a8eff00747>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Play_Store_data['Price'] = Play_Store_data['Price'].str.replace('$', '').astype(float)
# <ipython-input-29-c5a8eff00747>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Play_Store_data['Price'] = Play_Store_data['Price'].str.replace('$', '').astype(float)

# %%
Play_Store_data['Installs'] = Play_Store_data['Installs'].str.replace(',', '').str.replace('+', '').astype(int)
# Out:
# <ipython-input-30-cbc910dd5f12>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Play_Store_data['Installs'] = Play_Store_data['Installs'].str.replace(',', '').str.replace('+', '').astype(int)
# <ipython-input-30-cbc910dd5f12>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Play_Store_data['Installs'] = Play_Store_data['Installs'].str.replace(',', '').str.replace('+', '').astype(int)

# %%
#Top 10 Caterories which has most number of apps
top_cate=Play_Store_data['Category'].value_counts().head(10)
a=top_cate.index
top_cate
# Out:
# FAMILY             1832
# GAME                959
# TOOLS               828
# BUSINESS            420
# MEDICAL             395
# PERSONALIZATION     376
# PRODUCTIVITY        374
# LIFESTYLE           369
# FINANCE             345
# SPORTS              325
# Name: Category, dtype: int64

# %%
#Apps which is higest rating
Play_Store_data.nlargest(10, 'Rating',keep='first')
# Out:
#                                              App Category  Rating  Reviews  \
# 329                 Hojiboy Tojiboyev Life Hacks   COMICS     5.0       15
# 612                American Girls Mobile Numbers   DATING     5.0        5
# 615                                 Awake Dating   DATING     5.0        2
# 633                        Spine- The dating app   DATING     5.0        5
# 636   Girls Live Talk - Free Text and Video Chat   DATING     5.0        6
# 640                      Online Girls Chat Group   DATING     5.0        5
# 654              Speeding Joyride & Car Meet App   DATING     5.0        3
# 1028                            SUMMER SONIC app   EVENTS     5.0        4
# 1030                                  Prosperity   EVENTS     5.0       16
# 1038                   Mindvalley U Tallinn 2018   EVENTS     5.0        1
#
#       Size  Installs  Type  Price Content Rating  Genres    Last Updated  \
# ...

# %%
#How many installs are done
Installs_done=Play_Store_data['Installs'].value_counts()
Installs_done
# Out:
# 1000000       1417
# 100000        1112
# 10000         1031
# 10000000       937
# 1000           889
# 100            710
# 5000000        607
# 500000         505
# 50000          469
# 5000           468
# 10             385
# 500            328
# 50             204
# 50000000       202
# 100000000      188
# 5               82
# 1               67
# 500000000       24
# 1000000000      20
# 0               15
# Name: Installs, dtype: int64

# %%
#top 10 Genres
top_gen=Play_Store_data['Genres'].value_counts()
top_gen=top_gen.head(10)
top_gen
# Out:
# Tools              826
# Entertainment      561
# Education          510
# Business           420
# Medical            395
# Personalization    376
# Productivity       374
# Lifestyle          368
# Finance            345
# Sports             331
# Name: Genres, dtype: int64

# %%
#Size of maximum apps on play Store is
max_size=Play_Store_data['Size'].value_counts().head()
max_size
# Out:
# Varies with device    1227
# 11M                    182
# 12M                    181
# 14M                    177
# 13M                    177
# Name: Size, dtype: int64

# %%
#Content Rating of Apps
Content_raiting=Play_Store_data.groupby('Content Rating')['Installs'].sum()
Content_raiting
# Out:
# Content Rating
# Adults only 18+        2000000
# Everyone           52179353961
# Everyone 10+        4016271795
# Mature 17+          2437986878
# Teen               16487275393
# Unrated                  50500
# Name: Installs, dtype: int64

# %%
#Finding the mean rating of every catergory.
cate_mean=Play_Store_data.groupby('Category')['Rating'].mean().head(10)
cate_mean
# Out:
# Category
# ART_AND_DESIGN         4.350000
# AUTO_AND_VEHICLES      4.191765
# BEAUTY                 4.262264
# BOOKS_AND_REFERENCE    4.310360
# BUSINESS               4.136429
# COMICS                 4.182143
# COMMUNICATION          4.136190
# DATING                 4.019883
# EDUCATION              4.363025
# ENTERTAINMENT          4.135294
# Name: Rating, dtype: float64

# %%
#Maximum numbers of Android version
max_android=Play_Store_data['Android Ver'].value_counts().head(10)
max_android
# Out:
# 4.1 and up            2202
# 4.0.3 and up          1395
# 4.0 and up            1286
# Varies with device     990
# 4.4 and up             818
# 2.3 and up             616
# 5.0 and up             512
# 4.2 and up             372
# 2.3.3 and up           273
# 2.2 and up             239
# Name: Android Ver, dtype: int64

# %%
#Category which has large number of reviews
max_review=Play_Store_data.groupby('Category')['Reviews'].sum()
max_review=max_review.sort_values(ascending=False).head(10)
max_review
# Out:
# Category
# GAME               622298709
# COMMUNICATION      285811368
# TOOLS              229356597
# SOCIAL             227927801
# FAMILY             143825488
# PHOTOGRAPHY        105351270
# VIDEO_PLAYERS       67484568
# PRODUCTIVITY        55590649
# PERSONALIZATION     53543080
# SHOPPING            44551730
# Name: Reviews, dtype: int64

# %%
#number of free and paid apps
no_type=Play_Store_data['Type'].value_counts()
no_type
# Out:
# Free       8903
# Paid        756
# Unknown       1
# Name: Type, dtype: int64

# %%
#type which has more installs
max_type=Play_Store_data.groupby('Type')['Installs'].sum()
max_type
# Out:
# Type
# Free       75065573646
# Paid          57364881
# Unknown              0
# Name: Installs, dtype: int64

# %%
#mean rating of type of apps
Play_Store_data.groupby('Type')['Rating'].mean()
# Out:
# Type
# Free       4.171066
# Paid       4.247619
# Unknown    4.200000
# Name: Rating, dtype: float64

# %%
#Prices of most of the apps
paid_app=Play_Store_data[Play_Store_data['Type']=='Paid']
price=paid_app['Price'].value_counts().head(10)
price.head()
# Out:
# 0.99    145
# 2.99    124
# 1.99     73
# 4.99     70
# 3.99     57
# Name: Price, dtype: int64

# %%
#Install done according to sizes apps size
size_install=Play_Store_data.groupby('Size')['Installs'].sum()
size_install=size_install.sort_values(ascending=False).head(10)
size_install
# Out:
# Size
# Varies with device    43720380023
# 13M                    1598251835
# 76M                    1084110150
# 24M                    1028222460
# 17M                     992905856
# 11M                     952563201
# 70M                     793173100
# 40M                     787317270
# 74M                     627110600
# 57M                     603611000
# Name: Installs, dtype: int64

# %%
#Category which has large number of installs
max_install=Play_Store_data.groupby('Category')['Installs'].sum()
max_install=max_install.sort_values(ascending=False).head(10)
max_install
# Out:
# Category
# GAME                  13878924415
# COMMUNICATION         11038276251
# TOOLS                  8001772915
# PRODUCTIVITY           5793091369
# SOCIAL                 5487867902
# PHOTOGRAPHY            4649147655
# FAMILY                 4427941505
# VIDEO_PLAYERS          3926902720
# TRAVEL_AND_LOCAL       2894887146
# NEWS_AND_MAGAZINES     2369217760
# Name: Installs, dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# When i first loaded the data,i noticed that data was in inconsistant and also had lot of missing values and also duplicate data. So the first step was to find the missing data and replace it with appropriate data.And also to find Duplicate data and delete it to maintain the consistancy
# And i also Changed the data of two columns for getting valuable data insights.
# *   **Top 10 Caterories which has most number of apps:**
#
#     So here we found out which categoery has most numbers of apps on play store.It is give us the idea that i which category bussiness is likely to be succesced.
# *   **Apps which is higest rating :**
#
#     We are finding the heigest raiting app so we can get some idea from these app, which will help in improving aour app.
#
# *   **Number of installs done on play store :**
#
#     It shows us that the maximum numbers of app on play store has 1000000 downloads, so we can set our download targets accordingly.
# *   **Top Genres in playstores :**
#
#     So here we found out which categoery has most numbers of apps on play store.It is give us the idea that i which category bussiness is likely to be succesced.
#
# *  **Maximum numbers of Android version support apps have :**
#
#     Here we get to know maximum apps which suppourts particular android version.So it will be easy for us to make our app more compatable.
#
#
# *   **Size of maximum apps on play store :**
#
#     Here we get to know the maximum numbers of apps having a particular size .
#     Most of the apps varies but 11mb is the 2nd higest their it proves that less size is apprecitaed by the people ,maybe beacuse it fast to download.
# *   **Content Rating of Apps :**
#
#     Here we get to know what is the content rating of most of the app,which is Everyone,which will help to setting our app content rating.
# *   **Finding the mean rating of every catergory :**
#
#     Finding the average rating of every category which will help to get idea of all category in play store
#
# *   **Category which has large number of reviews :**
#
#     Because of this we can find out the categories that has maximum number of engagement.So if customer engagement is the main moto we can use this information.
# *   **Number of free and paid apps :**
#
#     Here we get to the numbers of free and paid apps on play store,so we can get the idea that what type of apps they prefer the most,which is mostly free apps.
#
# *   **Type which has more installs :**
#
#     Here we got to know that Free app have more download on play store than the paid apps.so we can get a idea for our app.
# *   **Mean rating of type of apps :**
#
#     Here we got to know the mean rating is more tha n free app,even though large number of installs of free type apps people liked the paid apps more.
#
# *   **Prices of most of the apps :**
#
#     So here we found the prefered price by the people app with minimum price because most apps on play store costs from 0.99$ to 2.99$.
# *   **Install done according to sizes apps size :**
#
#     Here we try to know about the prefered size of people on play store, and
#     we most of the apps sizes varies devices to devices.
# *   **Category which has large number of installs :**
#
#     Here we got to that even though Family categeory has large number of apps, But Games categeory has higest numbers of installs.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt_color=['purple','green','yellow','blue','pink','royalblue','tomato']
top_cate.plot(kind='bar',xlabel="Category",ylabel='Numbers of Apps',title='Top 10 Category',figsize=(15,5),color=plt_color)
# Out:
# <Axes: title={'center': 'Top 10 Category'}, xlabel='Category', ylabel='Numbers of Apps'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the app count  with respect to category, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# So here we found out which categoery has most numbers of apps on play store.So it will help us to choose the appropriate category for our app.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,as we know the top categery which has higest numbers of apps on the play store,it will help us by telling which category to focus on the play store.Its gives us the overall idea of dominating categeory on play stores. Even thought if bussiness make the app of dominant categeory it does not assures its success,becuse we dont know that wheather users like it or not.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
max_install.plot(kind='bar',xlabel="Categeory",ylabel='Numbers of Installs',title='Numbers of installs done',figsize=(15,5),color=plt_color)
# Out:
# <Axes: title={'center': 'Numbers of installs done'}, xlabel='Categeory', ylabel='Numbers of Installs'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar graph is used to compare the items between different Categeory. Bar graphs are used to measure the changes in count. When the changes are larger, a bar graph is the best option to represent the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found out that the Games categoery has most installs on play store. Games categoery has most engugment on this platform.which is followed by communication and tools.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It will help the company to know what kind of apps users like to to install the most. And in which categeory they can achieve the most engagement.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
max_review.plot(kind='bar',title='Top 10 Categories with most review',figsize=(15,5),color=plt_color)
# Out:
# <Axes: title={'center': 'Top 10 Categories with most review'}, xlabel='Category'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the review count  with respect to category, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we found out that most number of people in interacting with apps in the forms of review with the apps under the categeories like Games,Communication tools etc.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here we found out that user is mostly giving reviews to apps which comes  under the category of Games,Communication tools etc. Which teels us that User are really intrested in this categeories.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 3 visualization code
top_gen.plot(kind='pie',figsize=(20,7),
                               autopct="%1.1f%%",
                               startangle=90,
                               shadow=True,title='Top 10 genres')
# Out:
# <Axes: title={'center': 'Top 10 genres'}, ylabel='Genres'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is a type of graph in which a circle is divided into sectors that each represents a proportion of the whole. Pie charts are a useful way to organize data in order to see the size of components relative to the whole, and are particularly good at showing percentage or proportional data.
#
# Thus, I have used pie chart to show the percentage of top 10 genrs.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# So here we found out which genres has most numbers of apps on play store.So it will help us to choose the genres category for our app.
# Here we found out that play store mostly contains apps which comes under the genres of Tools,Enterteainment,Education,etc.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# here it will help apps in find out which genres is domiinating in the play store and make sutaible apps according to it.
# But making the apps of top genres does not assure you success,becuse we dont know that wheather users like it or not.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 13 visualization code
genr_install=Play_Store_data.groupby('Genres')['Installs'].sum().head(10)
genr_install=genr_install.sort_values(ascending=False)
genr_install.plot(kind='pie',figsize=(20,7),


                               title='Higest Installs per Genres ')
hole = plt.Circle((0, 0), 0.65, facecolor='white')
plt.gcf().gca().add_artist(hole)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Donut charts are used to show the proportions of categorical data, with the size of each piece representing the proportion of each category. A donut chart is created using a string field and a count of features, number, or rate/ratio field.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# So we found out that user installs the apps from genres like Arcade,Action,Adventure.Arcade has most engugment on this platform,which is followed by Action and Adventure.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here we under stand that Users are mostly intersted in apps which comes under the genres of Arcade,Action,Adventure. even though it is not the dominating genres.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
Content_raiting.plot(kind='pie',figsize=(20,7),
                               labeldistance=1.1,
                               title='Higest Content Rating')
hole = plt.Circle((0, 0), 0.65, facecolor='white')
plt.gcf().gca().add_artist(hole)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Donut charts are used to show the proportions of categorical data, with the size of each piece representing the proportion of each category. A donut chart is created using a string field and a count of features, number, or rate/ratio field.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found out that content rating of most of the apps on Play store which users like and install is Everyone,Everyone 10+,Mature 17+ etc.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It will help to know which content raiting is must be used in our app for better engsgement. Here we see that Everyone Content Rating is liked and install.And if we keep our content rating Everyone we are able to reachlarge number of users.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 2 visualization code
Installs_done.plot(kind='bar',xlabel="Installs Done",ylabel='Numbers of Apps',title='Numbers of installs done',figsize=(15,5),color=plt_color)
# Out:
# <Axes: title={'center': 'Numbers of installs done'}, xlabel='Installs Done', ylabel='Numbers of Apps'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the app count  with respect to category, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we found most of the apps on play store achieve the mark of 10,00,000 marks which is followed by 1,00,000.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# So after locking at this chart we get to know that most apps has achieve the target of 10,00,000 installs so our initail goal should also be the same.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
size_install.plot(kind='barh',xlabel="Installs Count",ylabel='Size of Apps',title='Top 10 App sizes',figsize=(15,5),color=plt_color)
# Out:
# <Axes: title={'center': 'Top 10 App sizes'}, xlabel='Installs Count', ylabel='Size of Apps'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar graph helps us visualize and compare data for different categories or items. It brings the categories into focus and helps us visualize data with bars of different sizes and colors. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the app size with respect to count, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we found out that the top ten app sizes which users prefer the top of which is Varies with devices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Users prefer the top of which is Varies with devices,but when we look at rest of the top 2-10 apps sizes we notice that all are ub=nder 90 mb. So best case will be to keep app size under 80 mb size.

# %% [markdown]
# #### Chart - 9

# %%
no_type.plot(kind='barh',ylabel="Category",xlabel='Numbers of Apps',title='Types of apps in play store',figsize=(15,5),color=plt_color)
# Out:
# <Axes: title={'center': 'Types of apps in play store'}, xlabel='Numbers of Apps', ylabel='Category'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar graph helps us visualize and compare data for different categories or items. It brings the categories into focus and helps us visualize data with bars of different sizes and colors. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the app type with respect to count, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we found out that mos tof the apps on play store are free and very less apps on play store is Paid.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# While looking at these at these data we know tha most of the apps on play store are Free, So the best choice is to keep the apps Free.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
max_type.plot(kind='pie',figsize=(20,7),
                               autopct="%1.1f%%",
                               startangle=90,
                               title='Installs of App types')
# Out:
# <Axes: title={'center': 'Installs of App types'}, ylabel='Installs'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is a type of graph in which a circle is divided into sectors that each represents a proportion of the whole. Pie charts are a useful way to organize data in order to see the size of components relative to the whole, and are particularly good at showing percentage or proportional data.
#
# Thus, I have used pie chart to show the percentage of Types of apps which is mostly installed.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we got to know that that most of user on playstore like install free apps. which is above 90%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here we got to know that that most of user on playstore like install free apps. which is above 90%. Here keep your app free dosent conferm the success,but it can help in success.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
price.plot(kind='barh',xlabel="Category",ylabel='Numbers of Apps',title='Types of apps in play store',figsize=(15,5),color=plt_color)
# Out:
# <Axes: title={'center': 'Types of apps in play store'}, xlabel='Category', ylabel='Numbers of Apps'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar graph helps us visualize and compare data for different categories or items. It brings the categories into focus and helps us visualize data with bars of different sizes and colors. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the app price with respect to count, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we got if that most of the paid price of 0.99% to 2.99$.This is the price of most of the apps on play store.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We know that the best pratice to keep the apps free, but if we had to make a paid app, we should price these app between  0.99% to 2.99$ which is appricate more by the users.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
cate_mean.plot(kind='bar',xlabel="Category",ylabel='Raiting',title='Average rating',figsize=(15,5),color=plt_color)
# Out:
# <Axes: title={'center': 'Average rating'}, xlabel='Category', ylabel='Raiting'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable. Sometimes, bar charts show other statistics, such as percentages.
#
# To show the app rating  with respect to category, I have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we found out that the average rating of these is above 4 out of five.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As we know the average value of rating of most of the categories is 4 and above so our target must be to achieve that target.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Chart - 4 visualization code
max_android.plot(kind='pie',figsize=(20,7),
                               autopct="%1.1f%%",
                               startangle=90,
                               title='Top 10 Android version support')
# Out:
# <Axes: title={'center': 'Top 10 Android version support'}, ylabel='Android Ver'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is a type of graph in which a circle is divided into sectors that each represents a proportion of the whole. Pie charts are a useful way to organize data in order to see the size of components relative to the whole, and are particularly good at showing percentage or proportional data.
#
# Thus, I have used pie chart to show the percentage of Android version of apps which is mostly installed.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we get know that most of the app has the compatiblity of 4.1,4.0.3,4.0 and up.Which will help us in deciding our apps complatiblity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# by these graph we got know that most of the app has the compatiblity of 4.1,4.0.3,4.0 and up.So the best pratice is to give the android version from Android 4.0 and above.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
sns.heatmap(Play_Store_data.corr(),cmap="Blues")
# Out:
# <ipython-input-59-852afcfd1d5f>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(Play_Store_data.corr(),cmap="Blues")
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation matrix is a table showing correlation coefficients between variables. Each cell in the table shows the correlation between two variables. A correlation matrix is used to summarize data, as an input into a more advanced analysis, and as a diagnostic for advanced analyses. The range of correlation is [-1,1].
#
# Thus to know the correlation between all the variables along with the correlation coeficients, i used correlation heatmap.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above correlation heatmap, we can see Install,Review,Price,Raiting are positiveliy highly correlated with a value of 1.
#
# Reviews is positively correlated only with Install and negative correlated with rest variables.
#
# Rest all correlation can be depicted from the above chart.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(data=Play_Store_data)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plot is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters. It also helps to form some simple classification models by drawing some simple lines or make linear separation in our data-set.
#
# Thus, I used pair plot to analyse the patterns of data and realationship between the features. It's exactly same as the correlation map but here you will get the graphical representation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart I got to know, there are less linear relationship between variables and data points are linearly separable. Play store data is clusetered and ovearlapped each other. In this whole pair plot, the importance of installs can be seen and the number of Installs with respect to different features are really insightful. Rest insights can be depicted from the above graph.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# *   I would like to suggest the client the try to make app in categeories which has most install like Games,Social,Tools etc.
#
# *   Client should try to make apps in Top installed genres like action,arcane,adventure tec,because it liked by most of the users.
#
#
#
# *   Client should try ti give updates.
# *   Most apps has achieve the target of 10,00,000 installs so our initial goal should also be the same.
#
# *   We try to keep the size of app as small as possible,it will be best to keep under 80 mb.
# *   Client Should try to keep the app free to install.
#
# *   If in case we have to make paid app,Try to keep the price of the app between 0.99$-2.99$.
# *   Client Should try to give the support from andriod 4.0 and higher.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *   Users are likly to show intrest in Games category.
# *   And User are likely to prefer Action or Arcane genres.
# *   User tends to install free apps more tha paid apps.
# *   Apps size should be small as possible.
# *   Clients should give new updates.
# *   If you try to make paid apps try to make the cost less.
# *   Try to make the app which has Everyone Contant Rating.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
